# %%
import pandas as pd
import numpy as np

# %%
df_part1 = pd.read_csv("HDI_PART_1.csv",encoding='cp1252')
df_part1.shape
# Out:
# (14635, 19)

# %%
df_part2 = pd.read_csv("HDI_PART_2.csv",encoding='cp1252')
df_part2.shape
# Out:
# (14697, 21)

# %%
df_final = pd.concat([df_part1, df_part2], ignore_index=True)
df_final.shape
# Out:
# (29332, 21)

# %%
df_final.drop_duplicates(inplace=True)
df_final.shape
# Out:
# (21535, 21)

# %%
df_final.head()
# Out:
#   Country Name Country Code  \
# 0    Sri Lanka          LKA
# 1    Sri Lanka          LKA
# 2    Sri Lanka          LKA
# 3    Sri Lanka          LKA
# 4    Sri Lanka          LKA
#
#                                          Series Name        Series Code  \
# 0  Adjusted savings: net national savings (% of GNI)  NY.ADJ.NNAT.GN.ZS
# 1  Adjusted savings: particulate emission damage ...  NY.ADJ.DPEM.GN.ZS
# 2  Adolescents out of school (% of lower secondar...  SE.SEC.UNER.LO.ZS
# 3                 Agricultural land (% of land area)     AG.LND.AGRI.ZS
# 4  Agriculture, forestry, and fishing, value adde...     NV.AGR.TOTL.ZS
#
#       2009 [YR2009]      2010 [YR2010]      2011 [YR2011]      2012 [YR2012]  \
# 0  18.3390801838948                 ..                 ..                 ..
# 1   0.3459459340125  0.338675247253775  0.323451741018238  0.312740057995155
# 2                ..   9.13488006591797   9.57067966461182   9.51301002502441
# ...
